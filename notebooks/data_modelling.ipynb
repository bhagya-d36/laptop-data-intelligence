# %%
import pandas as pd
import numpy as np

# %%
df_store = pd.read_csv('laptop_store_info.csv')
df_store
# Out:
#     Brand                                     Model  \
# 0  Lenovo                  ThinkPad E14 Gen 5 (AMD)
# 1  Lenovo                ThinkPad E14 Gen 5 (Intel)
# 2      HP    HP ProBook 440 14 inch G11 Notebook PC
# 3      HP  HP ProBook 450 15.6 inch G10 Notebook PC
#
#                                        Price Details  \
# 0  {'Current Price': 'Not Available', 'Original P...
# 1  {'Current Price': '$1,019.00', 'Original Price...
# 2  {'Current Price': '$849.00', 'Original Price':...
# 3  {'Current Price': 'Not Available', 'Original P...
#
#                                         Availability  \
# 0  {'Status': 'Available Soon', 'Notes': ["PCMag ...
# 1  {'Status': 'Available', 'Notes': ["Status is '...
# 2  {'Status': 'Available', 'Notes': ['Expected to...
# 3  {'Status': 'Not Available', 'Notes': ['Key Spe...
#
#                                      Promos / Offers  \
# 0  ['Benefits from joining the free Lenovo Pro st...
# ...

# %%
df_specs = pd.read_csv('laptop_tech_specs.csv')
df_specs
# Out:
#     Brand                                     Model  \
# 0  Lenovo                  ThinkPad E14 Gen 5 (AMD)
# 1  Lenovo                ThinkPad E14 Gen 5 (Intel)
# 2      HP    HP ProBook 440 14 inch G11 Notebook PC
# 3      HP  HP ProBook 450 15.6 inch G10 Notebook PC
#
#                                            Processor  \
# 0  Processor\n\nProcessor Family\nAMD Ryzen™ 3 / ...
# 1  Processor\n\nProcessor Family\n13th Generation...
# 2  Family: Intel® Core™ Ultra 5 processor Intel® ...
# 3  Family: Intel® Pentium® processor 13 th Genera...
#
#                                     Operating System  \
# 0  Operating System\n\nOperating System **\n- Win...
# 1  Operating System\n\nOperating System **\n- Win...
# 2  Windows 11 Pro Windows 11 Pro Education Window...
# 3  Windows 11 Pro Windows 11 Pro Education Window...
#
#                                             Graphics  \
# 0  Graphics\n\nGraphics\n| Graphics             |...
# ...

# %%
df = pd.merge(df_store, df_specs, on='Model', how='inner')
df
# Out:
#   Brand_x                                     Model  \
# 0  Lenovo                  ThinkPad E14 Gen 5 (AMD)
# 1  Lenovo                ThinkPad E14 Gen 5 (Intel)
# 2      HP    HP ProBook 440 14 inch G11 Notebook PC
# 3      HP  HP ProBook 450 15.6 inch G10 Notebook PC
#
#                                        Price Details  \
# 0  {'Current Price': 'Not Available', 'Original P...
# 1  {'Current Price': '$1,019.00', 'Original Price...
# 2  {'Current Price': '$849.00', 'Original Price':...
# 3  {'Current Price': 'Not Available', 'Original P...
#
#                                         Availability  \
# 0  {'Status': 'Available Soon', 'Notes': ["PCMag ...
# 1  {'Status': 'Available', 'Notes': ["Status is '...
# 2  {'Status': 'Available', 'Notes': ['Expected to...
# 3  {'Status': 'Not Available', 'Notes': ['Key Spe...
#
#                                      Promos / Offers  \
# 0  ['Benefits from joining the free Lenovo Pro st...
# ...

# %%
df.to_csv('laptop_info.csv', index=False)

# %% [markdown]
# ----
